# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ------------------------------------- -- 11.0/11.6 MB 57.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 51.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 12.9/12.9 MB 67.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('apple_products.csv')

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.count() #total number of rows in dataframe
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Star Rating            62
# Ram                    62
# dtype: int64

# %%
df['Mrp'].max() #maximun value in the column
# Out:
# np.int64(149900)

# %%
df['Mrp'].min() #minimum value in the column
# Out:
# np.int64(39900)

# %%
df[df['Mrp']==149900]  #displaying the product which satisfies the given value
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900                    6                542                 42
# 41  149900                    6                545                 42
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
df[df['Mrp']>=100000] #displaying all the rows greater than the given value
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 18       APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 19          APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 21      APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 22          APPLE iPhone 11 Pro (Space Grey, 256 GB)
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)
# 25    APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 27            APPLE iPhone 12 Pro (Graphite, 256 GB)
# 30            APPLE iPhone 12 Pro (Graphite, 128 GB)
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# 32        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 37          APPLE iPhone 12 Pro Max (Silver, 128 GB)
# 39            APPLE iPhone 12 Pro Max (Gold, 128 GB)
# ...

# %%
df['Product Name']  #displaying the data in the column
# Out:
# 0            APPLE iPhone 8 Plus (Gold, 64 GB)
# 1     APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2         APPLE iPhone 8 Plus (Silver, 256 GB)
# 3              APPLE iPhone 8 (Silver, 256 GB)
# 4                APPLE iPhone 8 (Gold, 256 GB)
#                         ...
# 57              APPLE iPhone SE (Black, 64 GB)
# 58             APPLE iPhone 11 (Purple, 64 GB)
# 59              APPLE iPhone 11 (White, 64 GB)
# 60              APPLE iPhone 11 (Black, 64 GB)
# 61                APPLE iPhone 11 (Red, 64 GB)
# Name: Product Name, Length: 62, dtype: object

# %%
type(df['Product Name']) #checking the type of the column
# Out:
# pandas.core.series.Series

# %%
list(df['Product Name']) #Converting the series into list
# Out:
# ['APPLE iPhone 8 Plus (Gold, 64 GB)',
#  'APPLE iPhone 8 Plus (Space Grey, 256 GB)',
#  'APPLE iPhone 8 Plus (Silver, 256 GB)',
#  'APPLE iPhone 8 (Silver, 256 GB)',
#  'APPLE iPhone 8 (Gold, 256 GB)',
#  'APPLE iPhone 8 Plus (Silver, 64 GB)',
#  'APPLE iPhone 8 Plus (Space Grey, 64 GB)',
#  'APPLE iPhone 8 (Space Grey, 256 GB)',
#  'APPLE iPhone XS Max (Silver, 64 GB)',
#  'Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)',
#  'Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)',
#  'APPLE iPhone 11 Pro Max (Gold, 256 GB)',
#  'APPLE iPhone 11 Pro Max (Gold, 64 GB)',
#  'APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)',
#  'APPLE iPhone 11 Pro Max (Space Grey, 64 GB)',
#  'APPLE iPhone 11 Pro (Midnight Green, 64 GB)',
# ...

# %%
list(df['Product Name'])[32] #specific element in the list
# Out:
# 'APPLE iPhone 12 Pro Max (Graphite, 128 GB)'

# %%
list(df['Product Name'])[32].upper() #converting evryhting into uppercase
# Out:
# 'APPLE IPHONE 12 PRO MAX (GRAPHITE, 128 GB)'

# %%
list(df['Product Name'])[32][6:15].upper() #slicing the string
# Out:
# 'IPHONE 12'

# %%
list(df['Product Name'])[32][6:15].upper().strip() #getting rid of white spaces
# Out:
# 'IPHONE 12'

# %%
df['Model Name'] =  df['Product Name'].str[6:15]  #Created new column 'Model Name' and assgin a transformed value to it

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.sort_values(by=['Star Rating'])  #Sorting the values in ascending order based on column 'Star Rating'
# Out:
#                                         Product Name  \
# 3                    APPLE iPhone 8 (Silver, 256 GB)
# 4                      APPLE iPhone 8 (Gold, 256 GB)
# 7                APPLE iPhone 8 (Space Grey, 256 GB)
# 28               APPLE iPhone 12 Mini (White, 64 GB)
# 30            APPLE iPhone 12 Pro (Graphite, 128 GB)
# ..                                               ...
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# 7   https://www.flipkart.com/apple-iphone-8-space-...  Apple       77000
# ...

# %%
df.sort_values(by=['Star Rating'], ascending=False) #Sorting the values in descending order based on column 'Star Rating'
# Out:
#                                         Product Name  \
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# ..                                               ...
# 52                    APPLE iPhone SE (White, 64 GB)
# 53                   APPLE iPhone SE (Black, 128 GB)
# 57                    APPLE iPhone SE (Black, 64 GB)
# 54                   APPLE iPhone SE (White, 128 GB)
# 55                     APPLE iPhone SE (Red, 128 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# ...

# %%
df =df[df['Sale Price'] != df['Mrp']]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
[df['Mrp'] - df['Sale Price']]
# Out:
# [9     10901
#  10     7901
#  11    10901
#  12    10901
#  13    10901
#  18    31601
#  19    22400
#  21    22400
#  22    21400
#  23     9901
#  24     9000
#  25     9000
#  26    10000
#  27     9000
#  28    10000
#  29     9000
#  30     9000
#  31     9000
#  32     9000
#  33    10000
#  34    10000
#  35     9000
#  36     9000
#  37     9000
#  38    10000
#  39     9000
#  40     9000
#  41     9000
#  42     9000
#  43     9000
#  44     9000
#  45    10000
#  46     9000
#  47     9000
#  48     9000
#  49     9000
#  50     4901
#  51     4901
#  52     9901
#  53     9901
#  54     9901
#  55     9901
#  56     4901
#  57     9901
#  58     7901
#  59     7901
#  60     7901
#  61     7901
#  dtype: int64]

# %%
list(df['Mrp'] - df['Sale Price'])
# Out:
# [10901,
#  7901,
#  10901,
#  10901,
#  10901,
#  31601,
#  22400,
#  22400,
#  21400,
#  9901,
#  9000,
#  9000,
#  10000,
#  9000,
#  10000,
#  9000,
#  9000,
#  9000,
#  9000,
#  10000,
#  10000,
#  9000,
#  9000,
#  9000,
#  10000,
#  9000,
#  9000,
#  9000,
#  9000,
#  9000,
#  9000,
#  10000,
#  9000,
#  9000,
#  9000,
#  9000,
#  4901,
#  4901,
#  9901,
#  9901,
#  9901,
#  9901,
#  4901,
#  9901,
#  7901,
#  7901,
#  7901,
#  7901]

# %%
df = df.copy()

# %%
df['pricediff'] = list(df['Mrp'] - df['Sale Price'])  #calculating the discount price with the Mrp and selling price and assigning it to a new column 'pricediff'.

# %%
df.head()
# Out:
#                                          Product Name  \
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...
#
#                                           Product URL  Brand  Sale Price  \
# 9   https://www.flipkart.com/apple-iphone-xr-produ...  Apple       41999
# 10  https://www.flipkart.com/apple-iphone-xr-black...  Apple       39999
# 11  https://www.flipkart.com/apple-iphone-xr-coral...  Apple       41999
# 12  https://www.flipkart.com/apple-iphone-xr-black...  Apple       41999
# 13  https://www.flipkart.com/apple-iphone-xr-white...  Apple       41999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 9   52900                   20              79512               6796
# ...

# %%
df[df['pricediff']>=15000] # iphone which are at more than 15000 discount.
# Out:
#                                     Product Name  \
# 18   APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 19      APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 21  APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 22      APPLE iPhone 11 Pro (Space Grey, 256 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 18  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple       74999
# 19  https://www.flipkart.com/apple-iphone-11-pro-s...  Apple      117900
# 21  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117900
# 22  https://www.flipkart.com/apple-iphone-11-pro-s...  Apple       99900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 18  106600                   29               7088                523
# 19  140300                   15               7088                523
# 21  140300                   15               7088                523
# ...

# %%
df['Revenue'] = df['Sale Price'] * df['Number Of Ratings']  # Calculating total revenue on iphones

# %%
df.head()
# Out:
#                                          Product Name  \
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...
#
#                                           Product URL  Brand  Sale Price  \
# 9   https://www.flipkart.com/apple-iphone-xr-produ...  Apple       41999
# 10  https://www.flipkart.com/apple-iphone-xr-black...  Apple       39999
# 11  https://www.flipkart.com/apple-iphone-xr-coral...  Apple       41999
# 12  https://www.flipkart.com/apple-iphone-xr-black...  Apple       41999
# 13  https://www.flipkart.com/apple-iphone-xr-white...  Apple       41999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 9   52900                   20              79512               6796
# ...

# %%
df = df[df['Number Of Reviews']>=5000]  #Selecting rows having Number Of Reviews greater than 5000.

# %%
df.head(10)
# Out:
#                                          Product Name  \
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 52                     APPLE iPhone SE (White, 64 GB)
# 53                    APPLE iPhone SE (Black, 128 GB)
# 54                    APPLE iPhone SE (White, 128 GB)
# 55                      APPLE iPhone SE (Red, 128 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 9   https://www.flipkart.com/apple-iphone-xr-produ...  Apple       41999
# 10  https://www.flipkart.com/apple-iphone-xr-black...  Apple       39999
# 11  https://www.flipkart.com/apple-iphone-xr-coral...  Apple       41999
# 12  https://www.flipkart.com/apple-iphone-xr-black...  Apple       41999
# ...
